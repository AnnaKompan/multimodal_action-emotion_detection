# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %%
train_data = "./rgb_dataset/train"
test_data = "./rgb_dataset/test"

# %%
# classes = sorted([d for d in os.listdir(train_data) if d != '.DS_Store'])
classes = [d for d in os.listdir(train_data) if d != '.DS_Store']

print("Classes: ", classes)
# Out:
# Classes:  ['angry', 'confused', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'shy', 'surprise']

# %%
train_counts = {}
for cls in classes:
    cls_folder = os.path.join(train_data, cls)
    img = [im for im in os.listdir(cls_folder)]
    train_counts[cls] = len(img)
train_counts
# Out:
# {'angry': 2088,
#  'confused': 2088,
#  'disgust': 2088,
#  'fear': 2088,
#  'happy': 2088,
#  'neutral': 2088,
#  'sad': 2088,
#  'shy': 2088,
#  'surprise': 2088}

# %%
test_counts = {}
for cls in classes:
    cls_folder = os.path.join(test_data, cls)
    img = [im for im in os.listdir(cls_folder)]
    test_counts[cls] = len(img)
test_counts
# Out:
# {'angry': 290,
#  'confused': 290,
#  'disgust': 290,
#  'fear': 290,
#  'happy': 290,
#  'neutral': 290,
#  'sad': 290,
#  'shy': 290,
#  'surprise': 290}

# %%
sample_img = os.path.join(
        train_data,
        classes[1],
        os.listdir(os.path.join(train_data, classes[1]))[0])
sample_img = cv2.imread(sample_img)
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
plt.imshow(sample_img)

# %%
plt.figure(figsize=(10,6))

for i, cls in enumerate(classes):
    class_path = os.path.join(train_data, cls)
    first_img = os.listdir(class_path)[7]
    img_path = os.path.join(class_path, first_img)

    img = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
sizes = []
for cls in os.listdir(train_data):
    cls_path = os.path.join(train_data, cls)

    if not os.path.isdir(cls_path):
        continue
    for im in os.listdir(cls_path):
        img_path = os.path.join(cls_path, im)

        img = cv2.imread(img_path)
        h, w = img.shape[:2]
        sizes.append((w,h))

print("Img size: ", set(sizes))
# Out:
# Img size:  {(75, 75)}
